# %% [markdown]
# # Matplotlib 한글폰트 사용하기
# ## 1. 필요한 패키지 가져오기

# %%
# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 필요한 패키지와 라이브러리를 가져옴
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처 (matplotlib 3.4.0 기준 일부 폰트에서 여전히 깨짐 현상 발생)
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 2. 그래프를 그리기 위한 임의의 데이터를 만들어주기

# %%
import numpy as np

data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([ -88,  -56, -156, -209, -295, -296, -223, -268, -333, -400, -331,
#        -369, -304, -390, -351, -392, -365, -422, -481, -384, -457, -540,
#        -587, -513, -537, -468, -465, -487, -567, -644, -673, -583, -635,
#        -660, -738, -670, -665, -673, -717, -685, -709, -667, -635, -692,
#        -716, -717, -691, -628, -542, -570])

# %% [markdown]
# ## 3. 기본 폰트로 지정되었기 때문에 한글이 깨지는 상태

# %%
plt.plot(range(50), data, 'r')
plt.title('시간별 간격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %% [markdown]
# ## 4. 폰트 설정 전, 설치된 `matplotlib`의 버전과 위치정보 가져오기

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.2.2
# 설치 위치:  /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py
# 설정 위치:  /Users/heekyjung/.matplotlib
# 캐시 위치:  /Users/heekyjung/.matplotlib

# %% [markdown]
# ## 5. 터미널을 이용해 `matplotlib` 위치로 이동하기

# %%
print ('설정파일 위치: ', mpl.matplotlib_fname())해
# Out:
# 설정파일 위치:  /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc

# %% [markdown]
# ## 6. 설치된 폰트 찍어보기

# %%
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# ttf 폰트 전체갯수
print(len(font_list))
# Out:
# 409

# %%
# OSX 의 설치 된 폰트를 가져오는 함수
font_list_mac = fm.OSXInstalledFonts()
print(len(font_list_mac))
# Out:
# 409

# %%
# 시스템 폰트에서 읽어온 리스트에서 상위 10개만 출력
font_list[:10]
# Out:
# ['/System/Library/Fonts/Supplemental/Al Tarikh.ttc',
#  '/System/Library/Fonts/Supplemental/Bodoni 72 OS.ttc',
#  '/System/Library/Fonts/Supplemental/STIXIntSmReg.otf',
#  '/System/Library/Fonts/Supplemental/Arial Narrow.ttf',
#  '/System/Library/Fonts/Supplemental/DIN Condensed Bold.ttf',
#  '/System/Library/Fonts/Supplemental/Times New Roman Bold.ttf',
#  '/System/Library/Fonts/Supplemental/Krungthep.ttf',
#  '/Library/Fonts/a∞ÌµÒ10.otf',
#  '/System/Library/Fonts/Supplemental/NotoSansMandaic-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/Bradley Hand Bold.ttf']

# %%
f = [f.name for f in fm.fontManager.ttflist]
print(len(font_list))
# 10개의 폰트명만 출력
f[:10]
# Out:
# 409
# ['STIXGeneral',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'cmmi10',
#  'cmtt10',
#  'DejaVu Serif Display',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'cmex10']

# %%
# 전체 폰트네임 출력
# [f.name for f in fm.fontManager.ttflist if '' in f.name]

# %% [markdown]
# ## 7. 나눔고딕 사용을 위해 'Nanum'이 들어간 폰트만 가져오기
# - 폰트를 설치했는데 원하는 폰트명을 못 가져온다면, 터미널을 열어 `mpl.get_cachedir()`로 찍히는 캐시위치로 이동해서 캐시파일을 열어본다.
# - 캐시파일에 원하는 폰트리스트가 없으면 주피터노트북 혹은 콘다를 재실행한다.

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumSquareOTF', '/Users/heekyjung/Library/Fonts/NanumSquareR.otf'),
#  ('NanumSquare', '/Users/heekyjung/Library/Fonts/NanumSquareEB.ttf'),
#  ('NanumGothicCoding',
#   '/Users/heekyjung/Library/Fonts/NanumGothicCodingBold.ttf'),
#  ('NanumMyeongjo',
#   '/Users/heekyjung/Library/Fonts/NanumMyeongjoExtraBold.ttf'),
#  ('NanumBarunGothic',
#   '/Users/heekyjung/Library/Fonts/NanumBarunGothicUltraLight.ttf'),
#  ('NanumBarunpen', '/Users/heekyjung/Library/Fonts/NanumBarunpenB.ttf'),
#  ('NanumGothicOTF', '/Users/heekyjung/Library/Fonts/NanumGothicBold.otf'),
#  ('NanumMyeongjoOTF',
#   '/Users/heekyjung/Library/Fonts/NanumMyeongjoExtraBold.otf'),
#  ('NanumGothicOTF', '/Users/heekyjung/Library/Fonts/NanumGothicExtraBold.otf'),
#  ('NanumBarunGothic',
#   '/Users/heekyjung/Library/Fonts/NanumBarunGothicLight.ttf'),
#  ('NanumMyeongjo', '/Users/heekyjung/Library/Fonts/NanumMyeongjoBold.ttf'),
#  ('NanumMyeongjoOTF', '/Users/heekyjung/Library/Fonts/NanumMyeongjoBold.otf'),
# ...

# %% [markdown]
# ## 9. 폰트를 사용하는 방법은 3가지가 있습니다.
# 1. `FontProperties` 사용하기: 그래프에서 폰트가 필요한 항목마다 지정해야 함
# 2. `matplotlib.rcParams[]`로 전역글꼴 설정: 그래프에 설정하면 폰트가 필요한 항목에 적용됨
# 3. 2번의 방법을 `mpl.matplotlib_fname()`로 읽어지는 설정 파일에 직접 적어주기 (모든 노트북에 적용되며, 노트북을 열 때마다 지정할 필요가 없어 편리함)

# %% [markdown]
# ### 1. `FontProperties` 사용하기
# - 텍스트를 지정하는 항목에 사용한다. 지정한 항목에만 해당 폰트가 적용된다.
# - `matplotlib.pyplot`
#     - `title()`
#     - `xlabel()`
#     - `ylabel()`
#     - `legend()`
#     - `text()`
# - `matplotlib.axes`
#     - `set_title()`

# %%
# fname 옵션을 사용하는 방법
path = '/Users/heekyjung/Library/Fonts/NanumBarunpenR.ttf'
fontprop = fm.FontProperties(fname=path, size=18)

plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이', fontproperties=fontprop)
plt.ylabel('주식 가격', fontproperties=fontprop)
plt.xlabel('시간(분)', fontproperties=fontprop)
plt.show()

# %% [markdown]
# ### 2. `matplotlib.rcParams[]`로 전역글꼴 설정

# %%
# 기본 설정 읽기
import matplotlib.pyplot as plt

# size, family
print('# 설정 되어있는 폰트 사이즈')
print (plt.rcParams['font.size'] ) 
print('# 설정 되어있는 폰트 글꼴')
print (plt.rcParams['font.family'] )
# Out:
# # 설정 되어있는 폰트 사이즈
# 10.0
# # 설정 되어있는 폰트 글꼴
# ['sans-serif']

# %%
# serif, sans-serif, monospace
print('serif 세리프가 있는 폰트--------')
print (plt.rcParams['font.serif']) 
print('sans-serif 세리프가 없는 폰트--------')
print (plt.rcParams['font.sans-serif']) 
print('monospace 고정폭 글꼴--------')
print (plt.rcParams['font.monospace'])
# Out:
# serif 세리프가 있는 폰트--------
# ['DejaVu Serif', 'Bitstream Vera Serif', 'Computer Modern Roman', 'New Century Schoolbook', 'Century Schoolbook L', 'Utopia', 'ITC Bookman', 'Bookman', 'Nimbus Roman No9 L', 'Times New Roman', 'Times', 'Palatino', 'Charter', 'serif']
# sans-serif 세리프가 없는 폰트--------
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# monospace 고정폭 글꼴--------
# ['DejaVu Sans Mono', 'Bitstream Vera Sans Mono', 'Computer Modern Typewriter', 'Andale Mono', 'Nimbus Mono L', 'Courier New', 'Courier', 'Fixed', 'Terminal', 'monospace']

# %%
plt.rcParams['font.family'] = 'Nanum Brush Script'
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (14,4)

# %%
plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('seaborn-pastel')
plt.show()

# %% [markdown]
# #### `rcParams` 대신 `FontProperties`와 `plt.rc`를 사용하는 방법

# %%
path = '/Users/heekyjung/Library/Fonts/NanumBarunGothic.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
print(font_name)
plt.rc('font', family=font_name)

fig, ax = plt.subplots()
ax.plot(data)
ax.set_title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
plt.style.use('ggplot')
plt.show()
# Out:
# NanumBarunGothic

# %% [markdown]
# ### 3. `rcParams`를 설정파일에 직접 적어주는 방법 - 모든 노트북에 공통적용
# - `font.family: NanumGothicOTF`
# - 이외에 자주 사용하는 설정도 함께 해주면 편리하다.
# - 이곳에서 폰트를 지정하면 노트북을 실행할 때 바로 로드되도록 설정할 수 있다.

# %%
print ('설정파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정파일 위치:  /opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
# import matplotlib.pyplot as plt
# import numpy as np

fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('숫자 분포도 보기')
plt.show()

# %% [markdown]
# 참고 URL:
# - [font_manager — Matplotlib documentation](https://matplotlib.org/stable/api/font_manager_api.html)
# - [Customizing matplotlib — Matplotlib documentation](https://matplotlib.org/stable/tutorials/introductory/customizing.html)
# - [마이너스 폰트가 깨지는 문제 unicode_minus.py — Matplotlib 2.0.2 documentation](https://matplotlib.org/2.0.2/examples/api/unicode_minus.html)
# - https://financedata.github.io/posts/matplotlib-hangul-for-osx.html
